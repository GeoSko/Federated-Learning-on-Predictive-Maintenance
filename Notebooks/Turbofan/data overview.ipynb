# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "/content/drive/MyDrive/Thesis/Datasets/Turbofan_Dataset/final_datasets_non_normalized/"

# %%
df_train = pd.read_csv(path + "TRAINING_SET_FULL.csv")
df_test = pd.read_csv(path + "TEST_SET_FULL.csv")

df_alice = pd.read_csv(path + "TRAINING_SET_1.csv")
df_bob = pd.read_csv(path + "TRAINING_SET_2.csv")

# %%
df_train
# Out:
#         id  cycle  setting1  setting2  ...    s20      s21  RUL  fail_30
# 0        1      1   -0.0007   -0.0004  ...  39.06  23.4190  191        0
# 1        1      2    0.0019   -0.0003  ...  39.00  23.4236  190        0
# 2        1      3   -0.0043    0.0003  ...  38.95  23.3442  189        0
# 3        1      4    0.0007    0.0000  ...  38.88  23.3739  188        0
# 4        1      5   -0.0019   -0.0002  ...  38.90  23.4044  187        0
# ...    ...    ...       ...       ...  ...    ...      ...  ...      ...
# 20626  100    196   -0.0004   -0.0003  ...  38.49  22.9735    4        1
# 20627  100    197   -0.0016   -0.0005  ...  38.30  23.1594    3        1
# 20628  100    198    0.0004    0.0000  ...  38.44  22.9333    2        1
# 20629  100    199   -0.0011    0.0003  ...  38.29  23.0640    1        1
# 20630  100    200   -0.0032   -0.0005  ...  38.37  23.0522    0        1
#
# [20631 rows x 28 columns]

# %%
df_train.dtypes
# Out:
# id            int64
# cycle         int64
# setting1    float64
# setting2    float64
# setting3    float64
# s1          float64
# s2          float64
# s3          float64
# s4          float64
# s5          float64
# s6          float64
# s7          float64
# s8          float64
# s9          float64
# s10         float64
# s11         float64
# s12         float64
# s13         float64
# s14         float64
# s15         float64
# s16         float64
# s17           int64
# s18           int64
# s19         float64
# s20         float64
# s21         float64
# RUL           int64
# fail_30       int64
# dtype: object

# %%
df_train.describe()
# Out:
#                  id         cycle  ...           RUL       fail_30
# count  20631.000000  20631.000000  ...  20631.000000  20631.000000
# mean      51.506568    108.807862  ...    107.807862      0.150259
# std       29.227633     68.880990  ...     68.880990      0.357334
# min        1.000000      1.000000  ...      0.000000      0.000000
# 25%       26.000000     52.000000  ...     51.000000      0.000000
# 50%       52.000000    104.000000  ...    103.000000      0.000000
# 75%       77.000000    156.000000  ...    155.000000      0.000000
# max      100.000000    362.000000  ...    361.000000      1.000000
#
# [8 rows x 28 columns]

# %%
df_train['cycle'].describe()
# Out:
# count    20631.000000
# mean       108.807862
# std         68.880990
# min          1.000000
# 25%         52.000000
# 50%        104.000000
# 75%        156.000000
# max        362.000000
# Name: cycle, dtype: float64

# %%
# Whole dataset cycles
df_train[['id', 'cycle']].groupby('id').max().describe()
# Out:
#             cycle
# count  100.000000
# mean   206.310000
# std     46.342749
# min    128.000000
# 25%    177.000000
# 50%    199.000000
# 75%    229.250000
# max    362.000000

# %%
# Alice dataset cycles
df_alice[['id', 'cycle']].groupby('id').max().describe()
# Out:
#             cycle
# count   50.000000
# mean   198.180000
# std     34.455348
# min    128.000000
# 25%    172.250000
# 50%    195.000000
# 75%    214.750000
# max    287.000000

# %%
# Bob dataset cycles
df_bob[['id', 'cycle']].groupby('id').max().describe()
# Out:
#             cycle
# count   50.000000
# mean   214.440000
# std     54.927841
# min    135.000000
# 25%    178.500000
# 50%    205.000000
# 75%    237.750000
# max    362.000000

# %%
# df_train.std() == 0

# %%
df_train['fail_30'].value_counts()
# Out:
# 0    17531
# 1     3100
# Name: fail_30, dtype: int64

# %%
df_test['fail_30'].value_counts()
# Out:
# 0    12764
# 1      332
# Name: fail_30, dtype: int64

# %%
df_alice['fail_30'].value_counts()
# Out:
# 0    8359
# 1    1550
# Name: fail_30, dtype: int64

# %%
df_bob['fail_30'].value_counts()
# Out:
# 0    9172
# 1    1550
# Name: fail_30, dtype: int64

# %%
sns.countplot(x = 'fail_30', data=df_train)

# %%
sns.countplot(x = 'fail_30', data=df_test)

# %%
corr_matrix = df_train.corr()
# corr_matrix

# %%
corr_matrix[['fail_30']].sort_values(by=['fail_30'], ascending= False)
# Out:
#                fail_30
# fail_30   1.000000e+00
# s11       6.656552e-01
# s4        6.484064e-01
# s15       6.187318e-01
# s17       5.830666e-01
# s2        5.814040e-01
# s3        5.618920e-01
# s8        5.429101e-01
# s13       5.399146e-01
# cycle     5.036790e-01
# s9        4.195389e-01
# s14       3.410628e-01
# s6        5.957942e-02
# setting1  1.049943e-02
# setting2  9.402176e-03
# s5        2.220435e-15
# s1        8.198058e-16
# s16      -3.382962e-16
# s10      -5.044491e-16
# id       -1.448230e-02
# RUL      -5.665959e-01
# s20      -5.999121e-01
# s21      -6.064804e-01
# s7       -6.255919e-01
# s12      -6.401737e-01
# setting3           NaN
# s18                NaN
# s19                NaN

# %%
# Full set RUL
df_max_rul = df_train[['id', 'RUL']].groupby('id').max().reset_index()
df_max_rul['RUL'].hist(bins=15, figsize=(15,7))
plt.xlabel('RUL')
plt.ylabel('frequency')
plt.show()

# %%
# Alice set RUL
df_max_rul = df_alice[['id', 'RUL']].groupby('id').max().reset_index()
df_max_rul['RUL'].hist(bins=15, figsize=(15,7))
plt.xlabel('RUL')
plt.ylabel('frequency')
plt.show()

# %%
# Full set RUL
df_max_rul = df_bob[['id', 'RUL']].groupby('id').max().reset_index()
df_max_rul['RUL'].hist(bins=15, figsize=(15,7))
plt.xlabel('RUL')
plt.ylabel('frequency')
plt.show()

# %%
# The smallest number of cycles of one engine in the test set
print(min([df_test[df_test['id'] == id].shape[0] for id in df_test['id'].unique()]))
# Out:
# 31
