# %% [markdown]
# # Import Libraries

# %%
# !pip install --quiet --upgrade tensorflow-federated
# !pip install --quiet --upgrade nest-asyncio

import nest_asyncio
nest_asyncio.apply()
# Out:
#      |████████████████████████████████| 819 kB 4.2 MB/s
#      |████████████████████████████████| 65.1 MB 89 kB/s
#      |████████████████████████████████| 887 kB 55.7 MB/s
#      |████████████████████████████████| 53 kB 2.1 MB/s
#      |████████████████████████████████| 121 kB 60.5 MB/s
#      |████████████████████████████████| 45 kB 3.6 MB/s
#      |████████████████████████████████| 237 kB 76.6 MB/s
#      |████████████████████████████████| 4.0 MB 45.3 MB/s
#      |████████████████████████████████| 251 kB 73.6 MB/s
#      |████████████████████████████████| 462 kB 74.8 MB/s
#      |████████████████████████████████| 4.2 MB 40.7 MB/s
#   Building wheel for jax (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 2.2.4 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.28.1 which is incompatible.
# pymc3 3.11.4 requires cachetools>=4.2.1, but you have cachetools 3.1.1 which is incompatible.
# panel 0.12.1 requires tqdm>=4.48.0, but you have tqdm 4.28.1 which is incompatible.
# fbprophet 0.7.1 requires tqdm>=4.36.1, but you have tqdm 4.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_federated as tff



SEED = 0
tf.random.set_seed(SEED)
np.random.seed(0)

tff.federated_computation(lambda: 'Hello, World!')()
# Out:
# b'Hello, World!'

# %%
from tensorflow import keras
from keras.metrics import BinaryAccuracy, Precision, Recall
from keras import layers

from sklearn.model_selection import GroupShuffleSplit

# %% [markdown]
# # Load Data

# %%
path = "/content/drive/MyDrive/Thesis/Datasets/Turbofan_Dataset/final_datasets_normalized/"

# %%
# Load data and drop irrelevant columns

alice_set = pd.read_csv(path + "TRAINING_SET_1.csv")
bob_set = pd.read_csv(path + "TRAINING_SET_2.csv")

test_set = pd.read_csv(path + "TEST_SET_FULL.csv")


drop_cols = ["cycle","setting3","s1","s5","s10","s16","s18","s19","RUL"]
corr_cols = ["s11","s4","s15","s17","s2","s3","s8","s13","s9","s14","s12","s7","s20"]
feature_cols = ['cycle_norm', 'setting1', 'setting2', 's2', 's3', 's4', 's6', 's7',
       's8', 's9', 's11', 's12', 's13', 's14', 's15', 's17', 's20', 's21']
prediction_col = 'fail_30'

alice_set = alice_set.drop(drop_cols, axis=1)
bob_set = bob_set.drop(drop_cols, axis=1)

test_set = test_set.drop(drop_cols, axis=1)

# %%
# Move cycle_norm column first for convenience

column_to_move = alice_set.pop("cycle_norm")
alice_set.insert(0, "cycle_norm", column_to_move)
column_to_move = bob_set.pop("cycle_norm")
bob_set.insert(0, "cycle_norm", column_to_move)

column_to_move = test_set.pop("cycle_norm")
test_set.insert(0, "cycle_norm", column_to_move)

# %%
alice_set.shape
# Out:
# (9909, 20)

# %%
bob_set.shape
# Out:
# (10722, 20)

# %%
test_set.shape
# Out:
# (13096, 20)

# %% [markdown]
# # Sequence Generation

# %%
# Receives single engine dataframe, window size and features -> sequences of length==window_size
def gen_train_data(df, sequence_length, columns):
    data = df[columns].values
    num_elements = data.shape[0]

    # -1 and +1 because of Python indexing
    for start, stop in zip(range(0, num_elements-(sequence_length-1)), range(sequence_length, num_elements+1)):
        yield data[start:stop, :]

# %%
# Generates sequences for multiple engines
def gen_data_wrapper(df, sequence_length, columns, ids=np.array([])):
    if ids.size <= 0:
        ids = df['id'].unique()
        
    data_gen = (list(gen_train_data(df[df['id']==id], sequence_length, columns))
               for id in ids)
    data_array = np.concatenate(list(data_gen)).astype(np.float32)
    return data_array

# %%
# Functions to generate sequences for the labals
def gen_labels(df, sequence_length, label):
    data_matrix = df[label].values
    num_elements = data_matrix.shape[0]

    # -1 because I want to predict the rul of that last row in the sequence, not the next row
    return data_matrix[sequence_length-1:num_elements, :]  

def gen_label_wrapper(df, sequence_length, label, ids=np.array([])):
    if ids.size <= 0:
        ids = df['id'].unique()
        
    label_gen = [gen_labels(df[df['id']==id], sequence_length, label) 
                for id in ids]
    label_array = np.concatenate(label_gen).astype(np.float32)
    return label_array

# %%
def gen_test_data(df, sequence_length, columns, mask_value):
    if df.shape[0] < sequence_length:
        data_matrix = np.full(shape=(sequence_length, len(columns)), fill_value=mask_value) # pad
        idx = data_matrix.shape[0] - df.shape[0]
        data_matrix[idx:,:] = df[columns].values  # fill with available data
    else:
        data_matrix = df[columns].values
        
    # specifically yield the last possible sequence
    stop = num_elements = data_matrix.shape[0]
    start = stop - sequence_length
    for i in list(range(1)):
        yield data_matrix[start:stop, :]
def gen_test_label_wrapper(df, sequence_length, label, ids=np.array([])):
    if ids.size <= 0:
        ids = df['id'].unique()
    
    label_gen = [gen_labels(df[df['id']==id], sequence_length, label) 
                for id in ids]
    # keep only last window
    if sequence_length > 31:
      print("Too big window")
    else:
      last_labels = [label[-1] for label in label_gen] 
      



    last_labels = np.concatenate(last_labels).astype(np.float32)
    # return label_array
    return last_labels

# %%
# Functions to generate sequences for the labals
def gen_labels(df, sequence_length, label):
    data_matrix = df[label].values
    num_elements = data_matrix.shape[0]

    # -1 because I want to predict the rul of that last row in the sequence, not the next row
    return data_matrix[sequence_length-1:num_elements, :]  

def gen_label_wrapper(df, sequence_length, label, ids=np.array([])):
    if ids.size <= 0:
        ids = df['id'].unique()
        
    label_gen = [gen_labels(df[df['id']==id], sequence_length, label) 
                for id in ids]
    label_array = np.concatenate(label_gen).astype(np.float32)
    return label_array

# %%
def gen_test_data(df, sequence_length, columns, mask_value):
    if df.shape[0] < sequence_length:
        data_matrix = np.full(shape=(sequence_length, len(columns)), fill_value=mask_value) # pad
        idx = data_matrix.shape[0] - df.shape[0]
        data_matrix[idx:,:] = df[columns].values  # fill with available data
    else:
        data_matrix = df[columns].values
        
    # specifically yield the last possible sequence
    stop = num_elements = data_matrix.shape[0]
    start = stop - sequence_length
    for i in list(range(1)):
        yield data_matrix[start:stop, :]
def gen_test_label_wrapper(df, sequence_length, label, ids=np.array([])):
    if ids.size <= 0:
        ids = df['id'].unique()
    
    label_gen = [gen_labels(df[df['id']==id], sequence_length, label) 
                for id in ids]
    # keep only last window
    if sequence_length > 31:
      print("Too big window")
    else:
      last_labels = [label[-1] for label in label_gen] 
      
    last_labels = np.concatenate(last_labels).astype(np.float32)
    # return label_array
    return last_labels

# %%
sequence_length = 20

gss = GroupShuffleSplit(n_splits=1, train_size=0.80, random_state=42)


for alice_train_unit, alice_val_unit in gss.split(alice_set['id'].unique(), groups=alice_set['id'].unique()):
    alice_train_unit = alice_set['id'].unique()[alice_train_unit]  # gss returns indexes and index starts at 1
    alice_val_unit = alice_set['id'].unique()[alice_val_unit]

    train_split_array = gen_data_wrapper(alice_set, sequence_length, feature_cols, alice_train_unit)
    train_split_label = gen_label_wrapper(alice_set, sequence_length, ['fail_30'], alice_train_unit)
    
    val_split_array = gen_data_wrapper(alice_set, sequence_length, feature_cols, alice_val_unit)
    val_split_label = gen_label_wrapper(alice_set, sequence_length, ['fail_30'], alice_val_unit)

for bob_train_unit, bob_val_unit in gss.split(bob_set['id'].unique(), groups=bob_set['id'].unique()):
    bob_train_unit = bob_set['id'].unique()[bob_train_unit]  # gss returns indexes and index starts at 1
    bob_val_unit = bob_set['id'].unique()[bob_val_unit]

    train_split_array = gen_data_wrapper(bob_set, sequence_length, feature_cols, bob_train_unit)
    train_split_label = gen_label_wrapper(bob_set, sequence_length, ['fail_30'], bob_train_unit)
    
    val_split_array = gen_data_wrapper(bob_set, sequence_length, feature_cols, bob_val_unit)
    val_split_label = gen_label_wrapper(bob_set, sequence_length, ['fail_30'], bob_val_unit)

# create sequences train, test 
X_alice = gen_data_wrapper(alice_set, sequence_length, feature_cols)
X_bob = gen_data_wrapper(bob_set, sequence_length, feature_cols)

y_alice = gen_label_wrapper(alice_set, sequence_length, ['fail_30'])
y_bob = gen_label_wrapper(bob_set, sequence_length, ['fail_30'])


test_gen = (list(gen_test_data(test_set[test_set['id']==id], sequence_length, feature_cols, -99.))
           for id in test_set['id'].unique())
X_test = np.concatenate(list(test_gen)).astype(np.float32)

y_test = gen_test_label_wrapper(test_set, sequence_length, ['fail_30'])

# %%
y_test = y_test.reshape(100,1)

# %%
y_alice.shape
# Out:
# (8959, 1)

# %% [markdown]
# # Federated Dataset

# %%
BATCH_SIZE = 64

# %%
# y_alice = y_alice.astype(np.int32)
# y_bob = y_bob.astype(np.int32)

# %%
train_data, val_data = [], []

temp_dataset = tf.data.Dataset.from_tensor_slices((X_alice, y_alice)).batch(BATCH_SIZE)
train_data.append(temp_dataset)
temp_dataset = tf.data.Dataset.from_tensor_slices((X_bob, y_bob)).batch(BATCH_SIZE)
train_data.append(temp_dataset)

temp_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
val_data.append(temp_dataset.batch(1))

# %%
train_data
# Out:
# [<BatchDataset element_spec=(TensorSpec(shape=(None, 20, 18), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>,
#  <BatchDataset element_spec=(TensorSpec(shape=(None, 20, 18), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>]

# %%
val_data
# Out:
# [<BatchDataset element_spec=(TensorSpec(shape=(None, 20, 18), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>]

# %% [markdown]
# # Create Model

# %%
def input_spec():
    return (
        tf.TensorSpec([None, 20, 18], tf.float32),
        tf.TensorSpec([None, 1], tf.float32)
    )

def model_fn():
    model = tf.keras.models.Sequential([
        tf.keras.layers.InputLayer(input_shape=(20, 18)),                                       
        tf.keras.layers.LSTM(32, activation='tanh'),
        tf.keras.layers.Dense(1, activation='sigmoid'),
    ])

    return tff.learning.from_keras_model(
        model,
        input_spec=input_spec(),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[BinaryAccuracy(), Precision(), Recall()])

# %% [markdown]
# # Training

# %%
EPOCHS = 100

# %%
trainer = tff.learning.build_federated_averaging_process(
    model_fn,
    client_optimizer_fn=lambda: tf.keras.optimizers.Adam(),
    server_optimizer_fn=lambda: tf.keras.optimizers.Adam()
)

state = trainer.initialize()
train_hist = []
for i in range(EPOCHS):
    state, metrics = trainer.next(state, train_data)
    train_hist.append(metrics)

    print(f"\rRun {i+1}/{EPOCHS}", end="")
# Out:
# Run 100/100

# %%
train_hist
# Out:
# [OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.87662166),
#                             ('precision', 0.7327434),
#                             ('recall', 0.40064517),
#                             ('loss', 0.30962804),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8806257),
#                             ('precision', 0.74),
#                             ('recall', 0.42967743),
#                             ('loss', 0.3002979),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.88297474),
#                             ('precision', 0.7389474),
#                             ('recall', 0.4529032),
#                             ('loss', 0.2916085),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8840425),
#                             ('precision', 0.73410696),
#                             ('recall', 0.46935484),
#                             ('loss', 0.28358692),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8863915),
#                             ('precision', 0.73478264),
#                             ('recall', 0.49064517),
#                             ('loss', 0.27631932),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8878864),
#                             ('precision', 0.7354049),
#                             ('recall', 0.50387096),
#                             ('loss', 0.26963094),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8896482),
#                             ('precision', 0.73681796),
#                             ('recall', 0.5183871),
#                             ('loss', 0.2635125),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8908761),
#                             ('precision', 0.73592496),
#                             ('recall', 0.53129035),
#                             ('loss', 0.257676),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8931717),
#                             ('precision', 0.7383948),
#                             ('recall', 0.5490323),
#                             ('loss', 0.25245592),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8942929),
#                             ('precision', 0.73628694),
#                             ('recall', 0.5629032),
#                             ('loss', 0.24768505),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8966419),
#                             ('precision', 0.7397035),
#                             ('recall', 0.5793548),
#                             ('loss', 0.24314845),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8990444),
#                             ('precision', 0.7430639),
#                             ('recall', 0.59612906),
#                             ('loss', 0.23922822),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.8998452),
#                             ('precision', 0.7432432),
#                             ('recall', 0.6032258),
#                             ('loss', 0.23561834),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9008061),
#                             ('precision', 0.7444882),
#                             ('recall', 0.61),
#                             ('loss', 0.23225655),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.90267473),
#                             ('precision', 0.7483469),
#                             ('recall', 0.62064517),
#                             ('loss', 0.22906962),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9057712),
#                             ('precision', 0.7544796),
#                             ('recall', 0.6383871),
#                             ('loss', 0.22601536),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9086007),
#                             ('precision', 0.7593423),
#                             ('recall', 0.65548384),
#                             ('loss', 0.22301096),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9106828),
#                             ('precision', 0.7626058),
#                             ('recall', 0.6683871),
#                             ('loss', 0.22013421),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.91185737),
#                             ('precision', 0.7625951),
#                             ('recall', 0.6787097),
#                             ('loss', 0.21748517),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.91265815),
#                             ('precision', 0.7623656),
#                             ('recall', 0.68612903),
#                             ('loss', 0.21500501),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.91324544),
#                             ('precision', 0.7621756),
#                             ('recall', 0.6916129),
#                             ('loss', 0.21258864),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.91441995),
#                             ('precision', 0.76253945),
#                             ('recall', 0.7012903),
#                             ('loss', 0.21023804),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9154343),
#                             ('precision', 0.76337737),
#                             ('recall', 0.70870966),
#                             ('loss', 0.2080239),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.91612834),
#                             ('precision', 0.7629859),
#                             ('recall', 0.71548384),
#                             ('loss', 0.20589715),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9168224),
#                             ('precision', 0.7633197),
#                             ('recall', 0.72096777),
#                             ('loss', 0.20383923),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.91789013),
#                             ('precision', 0.7656463),
#                             ('recall', 0.72612906),
#                             ('loss', 0.20188604),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.91879773),
#                             ('precision', 0.7664529),
#                             ('recall', 0.73258066),
#                             ('loss', 0.19999067),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.92023915),
#                             ('precision', 0.7705526),
#                             ('recall', 0.73774195),
#                             ('loss', 0.19815646),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9214137),
#                             ('precision', 0.7731544),
#                             ('recall', 0.7432258),
#                             ('loss', 0.19639091),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9224815),
#                             ('precision', 0.7755853),
#                             ('recall', 0.7480645),
#                             ('loss', 0.19467552),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9231755),
#                             ('precision', 0.7772955),
#                             ('recall', 0.75096774),
#                             ('loss', 0.19295926),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9244568),
#                             ('precision', 0.780927),
#                             ('recall', 0.75548387),
#                             ('loss', 0.1912685),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.92499065),
#                             ('precision', 0.7820299),
#                             ('recall', 0.7580645),
#                             ('loss', 0.189671),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9257381),
#                             ('precision', 0.7843594),
#                             ('recall', 0.7603226),
#                             ('loss', 0.18810672),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.92579144),
#                             ('precision', 0.78405315),
#                             ('recall', 0.7612903),
#                             ('loss', 0.18659194),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9264855),
#                             ('precision', 0.7864982),
#                             ('recall', 0.7629032),
#                             ('loss', 0.1851403),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9268592),
#                             ('precision', 0.7879494),
#                             ('recall', 0.7635484),
#                             ('loss', 0.18374749),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9272863),
#                             ('precision', 0.78870434),
#                             ('recall', 0.76580644),
#                             ('loss', 0.18239714),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9272863),
#                             ('precision', 0.78889626),
#                             ('recall', 0.76548386),
#                             ('loss', 0.18108876),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.92755324),
#                             ('precision', 0.7896311),
#                             ('recall', 0.7664516),
#                             ('loss', 0.17981356),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.92798036),
#                             ('precision', 0.79038143),
#                             ('recall', 0.76870966),
#                             ('loss', 0.17859332),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9281405),
#                             ('precision', 0.79116863),
#                             ('recall', 0.76870966),
#                             ('loss', 0.17741428),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.92851424),
#                             ('precision', 0.79223365),
#                             ('recall', 0.77),
#                             ('loss', 0.17627707),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9289413),
#                             ('precision', 0.79434276),
#                             ('recall', 0.77),
#                             ('loss', 0.17517258),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.92963535),
#                             ('precision', 0.797),
#                             ('recall', 0.7712903),
#                             ('loss', 0.17407688),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.92968875),
#                             ('precision', 0.7968698),
#                             ('recall', 0.77193546),
#                             ('loss', 0.17301026),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93000907),
#                             ('precision', 0.79806733),
#                             ('recall', 0.7725806),
#                             ('loss', 0.17196968),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93054295),
#                             ('precision', 0.7999333),
#                             ('recall', 0.77387094),
#                             ('loss', 0.17096585),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93059635),
#                             ('precision', 0.80040056),
#                             ('recall', 0.77354836),
#                             ('loss', 0.17000557),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9307565),
#                             ('precision', 0.80100167),
#                             ('recall', 0.77387094),
#                             ('loss', 0.1691119),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9310768),
#                             ('precision', 0.80220515),
#                             ('recall', 0.7745161),
#                             ('loss', 0.16818526),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93134373),
#                             ('precision', 0.8031417),
#                             ('recall', 0.77516127),
#                             ('loss', 0.16722889),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93182427),
#                             ('precision', 0.8047476),
#                             ('recall', 0.7764516),
#                             ('loss', 0.16630873),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.931931),
#                             ('precision', 0.80549043),
#                             ('recall', 0.776129),
#                             ('loss', 0.16539155),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.932198),
#                             ('precision', 0.8066354),
#                             ('recall', 0.7764516),
#                             ('loss', 0.16447242),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93235815),
#                             ('precision', 0.807241),
#                             ('recall', 0.77677417),
#                             ('loss', 0.16354197),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9327852),
#                             ('precision', 0.8092039),
#                             ('recall', 0.77709675),
#                             ('loss', 0.16259961),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93321234),
#                             ('precision', 0.81033903),
#                             ('recall', 0.77870965),
#                             ('loss', 0.16166653),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9339064),
#                             ('precision', 0.81262594),
#                             ('recall', 0.78064513),
#                             ('loss', 0.16075511),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9341733),
#                             ('precision', 0.8139926),
#                             ('recall', 0.78064513),
#                             ('loss', 0.15985373),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93465376),
#                             ('precision', 0.8156124),
#                             ('recall', 0.7819355),
#                             ('loss', 0.15895908),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9349207),
#                             ('precision', 0.81698686),
#                             ('recall', 0.7819355),
#                             ('loss', 0.15805925),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93550795),
#                             ('precision', 0.8193788),
#                             ('recall', 0.78290325),
#                             ('loss', 0.15721457),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9358283),
#                             ('precision', 0.8206081),
#                             ('recall', 0.7835484),
#                             ('loss', 0.15637992),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93646896),
#                             ('precision', 0.8226351),
#                             ('recall', 0.7854839),
#                             ('loss', 0.15552679),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9365757),
#                             ('precision', 0.82319134),
#                             ('recall', 0.7854839),
#                             ('loss', 0.15472929),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.937163),
#                             ('precision', 0.82494086),
#                             ('recall', 0.7874194),
#                             ('loss', 0.15387656),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93737656),
#                             ('precision', 0.82605755),
#                             ('recall', 0.7874194),
#                             ('loss', 0.15303351),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9377503),
#                             ('precision', 0.8269101),
#                             ('recall', 0.7890323),
#                             ('loss', 0.15220481),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93812394),
#                             ('precision', 0.8279824),
#                             ('recall', 0.7903226),
#                             ('loss', 0.15139303),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9386045),
#                             ('precision', 0.83006096),
#                             ('recall', 0.79096776),
#                             ('loss', 0.15057418),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9388714),
#                             ('precision', 0.83124363),
#                             ('recall', 0.79129034),
#                             ('loss', 0.14977705),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9391917),
#                             ('precision', 0.83316344),
#                             ('recall', 0.79096776),
#                             ('loss', 0.1489857),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.93913835),
#                             ('precision', 0.8335602),
#                             ('recall', 0.79),
#                             ('loss', 0.14819466),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9395654),
#                             ('precision', 0.83469385),
#                             ('recall', 0.7916129),
#                             ('loss', 0.1474679),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9398324),
#                             ('precision', 0.83588696),
#                             ('recall', 0.7919355),
#                             ('loss', 0.14674409),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94020605),
#                             ('precision', 0.8369639),
#                             ('recall', 0.7932258),
#                             ('loss', 0.14603019),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9405798),
#                             ('precision', 0.8378103),
#                             ('recall', 0.7948387),
#                             ('loss', 0.1453244),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9404196),
#                             ('precision', 0.83718556),
#                             ('recall', 0.79451615),
#                             ('loss', 0.14464605),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9407399),
#                             ('precision', 0.8382053),
#                             ('recall', 0.7954839),
#                             ('loss', 0.1439878),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94079334),
#                             ('precision', 0.8382603),
#                             ('recall', 0.79580647),
#                             ('loss', 0.14333977),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94084674),
#                             ('precision', 0.8385452),
#                             ('recall', 0.79580647),
#                             ('loss', 0.14273173),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94106025),
#                             ('precision', 0.83899456),
#                             ('recall', 0.7967742),
#                             ('loss', 0.14214607),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94122046),
#                             ('precision', 0.8391585),
#                             ('recall', 0.79774195),
#                             ('loss', 0.14155631),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94170094),
#                             ('precision', 0.83987814),
#                             ('recall', 0.8003226),
#                             ('loss', 0.14096782),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9418611),
#                             ('precision', 0.8402707),
#                             ('recall', 0.80096775),
#                             ('loss', 0.14043121),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94207466),
#                             ('precision', 0.84048665),
#                             ('recall', 0.8022581),
#                             ('loss', 0.1398703),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94202125),
#                             ('precision', 0.8402027),
#                             ('recall', 0.8022581),
#                             ('loss', 0.13923384),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9422348),
#                             ('precision', 0.84087837),
#                             ('recall', 0.80290323),
#                             ('loss', 0.1385574),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9425551),
#                             ('precision', 0.8414305),
#                             ('recall', 0.80451614),
#                             ('loss', 0.13788281),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94319576),
#                             ('precision', 0.8432232),
#                             ('recall', 0.8067742),
#                             ('loss', 0.13718498),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9434093),
#                             ('precision', 0.84412956),
#                             ('recall', 0.8070968),
#                             ('loss', 0.13652274),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9434093),
#                             ('precision', 0.84412956),
#                             ('recall', 0.8070968),
#                             ('loss', 0.13586237),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9436229),
#                             ('precision', 0.84480435),
#                             ('recall', 0.80774194),
#                             ('loss', 0.13522096),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9439966),
#                             ('precision', 0.8463357),
#                             ('recall', 0.8083871),
#                             ('loss', 0.13462307),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9443169),
#                             ('precision', 0.84758365),
#                             ('recall', 0.80903226),
#                             ('loss', 0.13406605),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94469064),
#                             ('precision', 0.84864867),
#                             ('recall', 0.8103226),
#                             ('loss', 0.1335457),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.9451711),
#                             ('precision', 0.8500507),
#                             ('recall', 0.8119355),
#                             ('loss', 0.13308355),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.94554484),
#                             ('precision', 0.85087717),
#                             ('recall', 0.8135484),
#                             ('loss', 0.13268107),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))]),
#  OrderedDict([('broadcast', ()),
#               ('aggregation',
#                OrderedDict([('mean_value', ()), ('mean_weight', ())])),
#               ('train',
#                OrderedDict([('binary_accuracy', 0.945705),
#                             ('precision', 0.8512648),
#                             ('recall', 0.81419355),
#                             ('loss', 0.13227433),
#                             ('num_examples', 18731),
#                             ('num_batches', 293)]))])]

# %%
evaluator = tff.learning.build_federated_evaluation(model_fn)

# %%
federated_metrics = evaluator(state.model, val_data)
federated_metrics
# Out:
# OrderedDict([('eval',
#               OrderedDict([('binary_accuracy', 0.93),
#                            ('precision', 0.90909094),
#                            ('recall', 0.8),
#                            ('loss', 0.18721528),
#                            ('num_examples', 100),
#                            ('num_batches', 100)]))])

# %%
# state.model
